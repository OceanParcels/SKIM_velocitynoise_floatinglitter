# %%
# %pylab inline
from parcels import FieldSet, Field, ParticleSet, JITParticle, AdvectionRK4, ErrorCode, Variable
import matplotlib.patches as mpatches
import cartopy
from datetime import timedelta as delta
import matplotlib.pyplot as plt
from glob import glob
import numpy as np
import xarray as xr
from os import environ
import matplotlib.animation as animation
from matplotlib.collections import PatchCollection
from matplotlib.patches import Rectangle
import matplotlib.ticker as mticker
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def load_data(f):
    T = {}
    T['name'] = "skimulator_%s.nc" % f
    pfile = xr.open_dataset('/scratch/evansebille/%s' % T['name'], decode_cf=True)
    T['lon'] = np.ma.filled(pfile.variables['lon'], np.nan)
    T['lat'] = np.ma.filled(pfile.variables['lat'], np.nan)
    T['time'] = np.ma.filled(pfile.variables['time'], np.nan)
    return T

fsets = ['no_err', 'obs']
D = {}
for f in fsets:
    D[f] = load_data(f)

# %%
from matplotlib import colors
pylab.rcParams['figure.figsize'] = (8, 10)

projection = cartopy.crs.PlateCarree()
fig, ax = plt.subplots(2, 1, subplot_kw={'projection': projection})
if len(D) == 1:
    ax = [ax]

for i, f in enumerate(fsets):
    T = D[f]
    ax[i].coastlines()
    ax[i].add_feature(cartopy.feature.LAND)

    bins = [np.arange(260, 420, 1), np.arange(0, 85, 1)]
    lons = T['lon'][:, -73:-1]
    lats = T['lat'][:, -73:-1]
    D[f]['H'], xe, ye = np.histogram2d(lons[~np.isnan(lons)], lats[~np.isnan(lats)], bins=bins)
    xb = (xe[1:] + xe[:-1])/2
    yb = (ye[1:] + ye[:-1])/2

    levels = [10**x for x in np.arange(0, 4.5, 0.5)]
    co = ax[i].contourf(xb, yb, D[f]['H'].T, levels=levels, transform=cartopy.crs.PlateCarree(), norm=colors.LogNorm())
    ax[i].set_extent([bins[0][0], bins[0][-1], bins[1][0], bins[1][-1]], crs=cartopy.crs.PlateCarree())
    ax[i].set_title('Particle density in SKIMulator %s run' % f)
    fig.colorbar(co, ax=ax[i])

# cbaxes = fig.add_axes([0.1, 0.05, 0.8, 0.03]) 
# cb = plt.colorbar(co, orientation="horizontal", cax = cbaxes)

plt.tight_layout()
savefig('skimulator_histogram.pdf')

# %%
import scipy.stats
pylab.rcParams['figure.figsize'] = (8, 5)

R = []
for f in fsets:
    I= np.where(np.logical_and(D['no_err']['H'].flatten()>0, D[f]['H'].flatten()>0))[0]
    plt.plot(D['no_err']['H'].flatten()[I], D[f]['H'].flatten()[I],'.')
    a = scipy.stats.spearmanr(D['no_err']['H'].flatten()[I], D[f]['H'].flatten()[I])
    R.append(a[0])
    plt.title('R = %f' %a[0])
    plt.show()

# %%
pylab.rcParams['figure.figsize'] = (10, 7)
projection = cartopy.crs.PlateCarree()

for i, f in enumerate(fsets):
    print(f)
    T = D[f]
    fig, ax = plt.subplots(1, 1,subplot_kw={'projection': projection})
    ax.coastlines()
    ax.add_feature(cartopy.feature.LAND)

    plottimes = np.arange(np.min(T['time']), np.max(T['time']), dtype='datetime64[5D]')

    b = np.where(np.logical_and(T['time'] >= plottimes[0], T['time'] < plottimes[1]))
    scat = ax.scatter(T['lon'][b], T['lat'][b], s=3, transform=cartopy.crs.Geodetic())
    ax.set_extent([-100, 60, 0, 80], crs=cartopy.crs.PlateCarree())

    ttl = ax.set_title('particles on ' + str(plottimes[0])+' in SKIMulator %s run' % f)
    frames = np.arange(0, len(plottimes)-1)

    def animate(t):
        b = np.where(np.logical_and(T['time'] >= plottimes[t], T['time'] < plottimes[t+1]))
        scat.set_offsets(np.vstack((T['lon'][b], T['lat'][b])).transpose())
        ttl.set_text('particles on ' + str(plottimes[t]) +' in SKIMulator %s run' % f)
        return scat,

    ax.set_extent([-100, 60, 0, 80], crs=cartopy.crs.PlateCarree())
    anim = animation.FuncAnimation(fig, animate, frames=frames, interval=100, blit=True)
    anim
    anim.save(T['name'].replace('.nc', '.gif'), writer='imagemagick', fps=10)
# Out:
# no_err
# /home/staff/sebil001/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:14: FutureWarning: In the future, 'NAT < x' and 'x < NAT' will always be False.
#
# /home/staff/sebil001/miniconda2/lib/python2.7/site-packages/ipykernel_launcher.py:22: FutureWarning: In the future, 'NAT < x' and 'x < NAT' will always be False.
# obs
